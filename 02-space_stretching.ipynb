# %%
# Load libraries
import torch
import torch.nn as nn
from res.plot_lib import set_default, show_scatterplot, plot_bases
from matplotlib.pyplot import plot, title, axis

# %%
# Set style (needs to be in a new cell)
set_default()

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# **(?1)** Try this on
# - a CPU machine
# - a GPU machine

# %%
device
# Out:
# device(type='cpu')

# %%
# generate some points in 2-D space
n_points = 1000
X = torch.randn(n_points, 2).to(device)
colors = X[:, 0]
# use the first coordinate to represent the color of the point

show_scatterplot(X, colors, title='X (dataset)')
OI = torch.cat((torch.zeros(2, 2), torch.eye(2))).to(device)
# OI is a zero matrix (i.e. the O) concatenated with an identity matrix (i.e. the I)
plot_bases(OI)

# %% [markdown]
# **(?2)**
# - Read how acold wrote `show_scatterplot()`
# - Read how acold wrote `plot_bases()`

# %%
OI
# Out:
# tensor([[0., 0.],
#         [0., 0.],
#         [1., 0.],
#         [0., 1.]])

# %% [raw]
# torch.hcat((torch.zeros(2, 2), torch.eye(2)))

# %% [raw]
# AttributeError: module 'torch' has no attribute 'hcat'

# %% [raw]
# torch.vcat((torch.zeros(2, 2), torch.eye(2)))

# %% [raw]
# AttributeError: module 'torch' has no attribute 'vcat'

# %% [raw]
# help(torch.cat)

# %%
torch.cat((torch.zeros(2, 2), torch.eye(2)), dim=1)
# Out:
# tensor([[0., 0., 1., 0.],
#         [0., 0., 0., 1.]])

# %% [markdown]
# # Visualizing Linear Transformations
#
# * Generate a random matrix $W$
#
# $
# \begin{equation}
#     W = U
#   \left[ {\begin{array}{cc}
#    s_1 & 0 \\
#    0 & s_2 \\
#   \end{array} } \right]
#   V^\top
# \end{equation}
# $
# * Compute $y = Wx$
# * Larger singular values stretch the points
# * Smaller singular values push them together
# * $U, V$ rotate/reflect

# %% [markdown]
# __(?3)__
#
# - Ponder on what was declared above.
# - and why the `new_OI` below is given by `OI @ W` instead of `OI @ W.t()`

# %%
show_scatterplot(X, colors, title='X (dataset)')
plot_bases(OI)

for i in range(10):
    # create a random matrix
    W = torch.randn(2, 2).to(device)
    # transform points
    Y = X @ W.t()
    # compute singular values
    U, S, V = torch.svd(W)
    # plot transformed points
    show_scatterplot(Y, colors, title='y = Wx, singular values : [{:.3f}, {:.3f}]'.format(S[0], S[1]))
    # transform the basis
    new_OI = OI @ W
    # plot old and new basis
    plot_bases(OI)
    #plot_bases(new_OI)

# %%
W = torch.randn(2, 2)
U, S, V = torch.svd(W)
U.shape, S.shape, V.shape
# Out:
# (torch.Size([2, 2]), torch.Size([2]), torch.Size([2, 2]))

# %%
U.size()
# Out:
# torch.Size([2, 2])

# %% [raw]
# U.shape?

# %% [markdown]
# # Linear transformation with PyTorch

# %%
model = nn.Sequential(
        nn.Linear(2, 2, bias=False)
)
model.to(device)
with torch.no_grad():
    Y = model(X)
    show_scatterplot(Y, colors)
    plot_bases(model(OI))

# %% [markdown]
# __(?2)__
# - `with torch.no_grad():` probably just means that we don't want gradient descent here.
#     - But what will happen if we run the same code but w/o the `with torch.no_grad():`?
# - Why the unit vectors changed directions and not longer perpendicular to each other?<br> __Ans__: Because they are `model(OI)`, not `OI`.

# %% [raw]
# Y = model(X)
# show_scatterplot(Y, colors)
# plot_bases(model(OI))

# %% [raw]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-23-3d021b10e7d1> in <module>
#       1 Y = model(X)
# ----> 2 show_scatterplot(Y, colors)
#       3 plot_bases(model(OI))
#
# ~/git-repos/phunc20/pytorch-Deep-Learning/res/plot_lib.py in show_scatterplot(X, colors, title)
#      40 def show_scatterplot(X, colors, title=''):
#      41     colors = colors.cpu().numpy()
# ---> 42     X = X.cpu().numpy()
#      43     plt.figure()
#      44     plt.axis('equal')
#
# RuntimeError: Can't call numpy() on Tensor that requires grad. Use tensor.detach().numpy() instead.

# %% [markdown]
# # Non-linear Transform: Map Points to a Square
#
# * Linear transforms can rotate, reflect, stretch and compress, but cannot curve
# * We need non-linearities for this
# * Can (approximately) map points to a square by first stretching out by a factor $s$, then squashing with a tanh function
#
# $
#    f(x)= \tanh \left(
#   \left[ {\begin{array}{cc}
#    s & 0 \\
#    0 & s \\
#   \end{array} } \right]
#   x
#   \right)
# $

# %%
z = torch.linspace(-10, 10, 101)
s = torch.tanh(z)
plot(z.numpy(), s.numpy())
title('tanh() non linearity');

# %%
show_scatterplot(X, colors, title='X')
plot_bases(OI)

model = nn.Sequential(
        nn.Linear(2, 2, bias=False),
        nn.Tanh()
)

model.to(device)

for s in range(1, 6):
    W = s * torch.eye(2)
    model[0].weight.data.copy_(W)
    Y = model(X).data
    show_scatterplot(Y, colors, title=f'f(x), s={s}')
    plot_bases(OI, width=0.01)

# %% [markdown]
# # Visualize Functions Represented by Random Neural Networks

# %%
show_scatterplot(X, colors, title='x')
n_hidden = 5

# NL = nn.ReLU()
NL = nn.Tanh()

for i in range(5):
    # create 1-layer neural networks with random weights
    model = nn.Sequential(
            nn.Linear(2, n_hidden), 
            NL, 
            nn.Linear(n_hidden, 2)
        )
    model.to(device)
    with torch.no_grad():
        Y = model(X)
    show_scatterplot(Y, colors, title='f(x)')
#     plot_bases(OI)

# %%
# deeper network with random weights
show_scatterplot(X, colors, title='x')
n_hidden = 5

# NL = nn.ReLU()
NL = nn.Tanh()

for i in range(5):
    model = nn.Sequential(
        nn.Linear(2, n_hidden), 
        NL, 
        nn.Linear(n_hidden, n_hidden), 
        NL, 
        nn.Linear(n_hidden, n_hidden), 
        NL, 
        nn.Linear(n_hidden, n_hidden), 
        NL, 
        nn.Linear(n_hidden, 2)
    )
    model.to(device)
    with torch.no_grad():
        Y = model(X).detach()
    show_scatterplot(Y, colors, title='f(x)')
